# %% [markdown]
# # Class Task 2 (Pandas)
# # Name: Matti Ur Rehman

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## CLASS TASK 2a:
#
# ### DATASET:
# - IMDB-Movie-Data.csv

# %%
df = pd.read_csv('IMDB-Movie-Data.csv')

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# ## 1- Load the file IMDB-Movie-Data.csv in pandas and make title as index column

# %%
df = df.set_index('Title')

# %%
df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %% [markdown]
# ## 2- Display 5 most repeated values in Director Column

# %%
df['Director'].value_counts(sort=True).head()
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Name: Director, dtype: int64

# %% [markdown]
# ## 3- Filter all movies from Passengers to Gold using value  (loc)

# %%
df.loc['Passengers': 'Gold']
# Out:
#                                          Rank                       Genre  \
# Title
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# Rogue One                                  13     Action,Adventure,Sci-Fi
# Moana                                      14  Animation,Adventure,Comedy
# Colossal                                   15         Action,Comedy,Drama
# The Secret Life of Pets                    16  Animation,Adventure,Comedy
# Hacksaw Ridge                              17     Biography,Drama,History
# Jason Bourne                               18             Action,Thriller
# Lion                                       19             Biography,Drama
# Arrival                                    20        Drama,Mystery,Sci-Fi
# Gold                                       21    Adventure,Drama,Thriller
# ...

# %% [markdown]
# ## 4- Filter all movies from Passengers to Gold using position (iloc)

# %%
df.iloc[df.index.get_loc('Passengers'): df.index.get_loc('Gold')]
# Out:
#                                          Rank                       Genre  \
# Title
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# Rogue One                                  13     Action,Adventure,Sci-Fi
# Moana                                      14  Animation,Adventure,Comedy
# Colossal                                   15         Action,Comedy,Drama
# The Secret Life of Pets                    16  Animation,Adventure,Comedy
# Hacksaw Ridge                              17     Biography,Drama,History
# Jason Bourne                               18             Action,Thriller
# Lion                                       19             Biography,Drama
# Arrival                                    20        Drama,Mystery,Sci-Fi
#
# ...

# %% [markdown]
# ## 5- List all movies from year 2012

# %%
df[df.Year == 2012]
# Out:
#                             Rank                      Genre  \
# Title
# Prometheus                     2   Adventure,Mystery,Sci-Fi
# The Avengers                  77              Action,Sci-Fi
# The Dark Knight Rises        125            Action,Thriller
# The Place Beyond the Pines   136       Crime,Drama,Thriller
# Django Unchained             145              Drama,Western
# ...                          ...                        ...
# The Expendables 2            917  Action,Adventure,Thriller
# The Master                   930                      Drama
# End of Watch                 958       Crime,Drama,Thriller
# Rock of Ages                 973       Comedy,Drama,Musical
# Project X                    995                     Comedy
#
#                                                                   Description  \
# Title
# Prometheus                  Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ## 6- List all movies having runtime of 120 and above

# %%
df[df['Runtime (Minutes)'] >= 120]
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Suicide Squad               5    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# The Lost City of Z          9  Action,Adventure,Biography
# ...                       ...                         ...
# Queen of Katwe            975       Biography,Drama,Sport
# The Skin I Live In        980              Drama,Thriller
# Across the Universe       983       Drama,Fantasy,Musical
# Selma                     990     Biography,Drama,History
# Taare Zameen Par          992          Drama,Family,Music
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ## 7- List all movies having rating above 6

# %%
df[df.Rating > 6]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Taare Zameen Par          992        Drama,Family,Music
# Take Me Home Tonight      993      Comedy,Drama,Romance
# Project X                 995                    Comedy
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Step Up 2: The Streets    998       Drama,Music,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ## 8- List all movies having metascore above 50

# %%
df[df.Metascore > 50]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# La La Land                  7        Comedy,Drama,Music
# ...                       ...                       ...
# Scream 4                  974            Horror,Mystery
# Queen of Katwe            975     Biography,Drama,Sport
# The Skin I Live In        980            Drama,Thriller
# Across the Universe       983     Drama,Fantasy,Musical
# Martyrs                   989                    Horror
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ## 9- List all movies having metascore above 60 and ratings above 6 and year 2016

# %%
df[(df.Metascore > 50) & (df.Rating > 6) & (df.Year == 2016)]
# Out:
#                          Rank                       Genre  \
# Title
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# ...                       ...                         ...
# The Siege of Jadotville   939       Action,Drama,Thriller
# Kicks                     950                   Adventure
# Custody                   965                       Drama
# L'odyssée                 967         Adventure,Biography
# Queen of Katwe            975       Biography,Drama,Sport
#
#                                                                Description  \
# Title
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# ...

# %% [markdown]
# ## 10- List all movies directed by David Ayer or Adam Mckay and having ratings above 6

# %%
df[(df.Director == 'David Ayer') | (df.Director == 'Adam Mckay') & (df.Rating > 6)]
# Out:
#                Rank                     Genre  \
# Title
# Suicide Squad     5  Action,Adventure,Fantasy
# Fury            241          Action,Drama,War
# End of Watch    958      Crime,Drama,Thriller
#
#                                                      Description    Director  \
# Title
# Suicide Squad  A secret government agency recruits some of th...  David Ayer
# Fury           A grizzled tank commander makes tough decision...  David Ayer
# End of Watch   Shot documentary-style, this film follows the ...  David Ayer
#
#                                                           Actors  Year  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# Fury           Brad Pitt, Shia LaBeouf, Logan Lerman, Michael...  2014
# End of Watch   Jake Gyllenhaal, Michael Peña, Anna Kendrick, ...  2012
#
#                Runtime (Minutes)  Rating   Votes  Revenue (Millions)  \
# Title
# Suicide Squad                123     6.2  393727              325.02
# ...

# %% [markdown]
# ## 11- List the movie which has highest rating in 2016  (Hint: solve in two steps, first filter the data of 2016 and save in another variable and then filter the highest rating from that)

# %%
df[df['Year'] == 2016].sort_values(['Rating'], ascending=False)
# Out:
#                          Rank                    Genre  \
# Title
# Dangal                    118   Action,Biography,Drama
# Kimi no na wa              97  Animation,Drama,Fantasy
# Koe no katachi            862  Animation,Drama,Romance
# La La Land                  7       Comedy,Drama,Music
# Paint It Black            479                    Drama
# ...                       ...                      ...
# Satanic                   270                   Horror
# The Last Face              50                    Drama
# The Intent                891              Crime,Drama
# Tall Men                  648  Fantasy,Horror,Thriller
# Don't Fuck in the Woods    43                   Horror
#
#                                                                Description  \
# Title
# Dangal                   Former wrestler Mahavir Singh Phogat and his t...
# Kimi no na wa            Two strangers find themselves linked in a biza...
# ...

# %% [markdown]
# ## 12- List the movie which has highest metascore in 2016  (Hint: solve in two steps, first filter the data of 2016 and save in another variable and then filter the highest metascore from that)

# %%
df[df['Year'] == 2016].sort_values(['Metascore'], ascending=False)
# Out:
#                        Rank                  Genre  \
# Title
# Moonlight                42                  Drama
# Manchester by the Sea    22                  Drama
# Toni Erdmann            612           Comedy,Drama
# La La Land                7     Comedy,Drama,Music
# Paterson                208   Comedy,Drama,Romance
# ...                     ...                    ...
# The Whole Truth         629    Crime,Drama,Mystery
# Genius                  693        Biography,Drama
# Rules Don't Apply       748   Comedy,Drama,Romance
# Chalk It Up             779                 Comedy
# Shut In                 827  Drama,Horror,Thriller
#
#                                                              Description  \
# Title
# Moonlight              A chronicle of the childhood, adolescence and ...
# Manchester by the Sea  A depressed uncle is asked to take care of his...
# Toni Erdmann           A practical joking father tries to reconnect w...
# ...

# %% [markdown]
# ## 13- List the movie which has highest revenue in 2016  (Hint: solve in two steps, first filter the data of 2016 and save in another variable and then filter the highest revenue from that)

# %%
df[df['Year'] == 2016].sort_values(['Revenue (Millions)'], ascending=False)
# Out:
#                                 Rank                       Genre  \
# Title
# Rogue One                         13     Action,Adventure,Sci-Fi
# Finding Dory                     120  Animation,Adventure,Comedy
# Captain America: Civil War        36     Action,Adventure,Sci-Fi
# The Secret Life of Pets           16  Animation,Adventure,Comedy
# The Jungle Book                  126      Adventure,Drama,Family
# ...                              ...                         ...
# Transpecos                       943                    Thriller
# Custody                          965                       Drama
# L'odyssée                        967         Adventure,Biography
# Amateur Night                    978                      Comedy
# It's Only the End of the World   979                       Drama
#
#                                                                       Description  \
# Title
# Rogue One                       The Rebel Alliance makes a risky move to steal...
# ...

# %% [markdown]
# ## CLASS TASK 2b:
#
# ### DATASET:
# - t20.csv

# %% [markdown]
# ## 1- Load the t20 dataset

# %%
df2 = pd.read_csv('t20.csv')

# %%
df2.head()
# Out:
#    Sno                  Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 0    0         V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 1    1       RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 2    2         MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 3    3  Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# 4    4        BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66
#
#      BF      SR  100  50  0   4s   6s  Unnamed: 15
# 0  1907  138.07    0  24  2  247   71          NaN
# 1  1905  138.21    4  19  6  234  120          NaN
# 2  1810  134.58    2  15  2  215  113          NaN
# 3  1824  124.06    0   7  1  186   61          NaN
# 4  1571  136.21    2  13  3  199   91          NaN

# %% [markdown]
# ## 2- check the columns and values

# %%
df2.columns
# Out:
# Index(['Sno', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF',
#        'SR', '100', '50', '0', '4s', '6s', 'Unnamed: 15'],
#       dtype='object')

# %%
df2.values
# Out:
# array([[0, 'V Kohli (INDIA)', '2010-2019', ..., 247, 71, nan],
#        [1, 'RG Sharma (INDIA)', '2007-2019', ..., 234, 120, nan],
#        [2, 'MJ Guptill (NZ)', '2009-2019', ..., 215, 113, nan],
#        ...,
#        [1, 'Ziaur Rehman (Fin)', '2019-2019', ..., 0, 0, nan],
#        [2, 'M Zondeki (SA)', '2006-2006', ..., 0, 0, nan],
#        [3, 'Zulqarnain Haider (ESP)', '2019-2019', ..., 0, 0, nan]],
#       dtype=object)

# %% [markdown]
# ## 3- Drop column Unnamed: 15

# %%
df2.drop('Unnamed: 15', axis=1, inplace=True)

# %%
df2
# Out:
#       Sno                   Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       0          V Kohli (INDIA)  2010-2019   75    70  20  2633  94*
# 1       1        RG Sharma (INDIA)  2007-2019  104    96  14  2633  118
# 2       2          MJ Guptill (NZ)  2009-2019   83    80   7  2436  105
# 3       3   Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75
# 4       4         BB McCullum (NZ)  2005-2015   71    70  10  2140  123
# ...   ...                      ...        ...  ...   ...  ..   ...  ...
# 1849   49        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*
# 1850    0     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*
# 1851    1       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0
# 1852    2           M Zondeki (SA)  2006-2006    1     1   0     0    0
# 1853    3  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0
#
#         Ave    BF      SR  100  50  0   4s   6s
# 0     52.66  1907  138.07    0  24  2  247   71
# ...

# %% [markdown]
# ## 4- Drop column Sno

# %%
df2.drop('Sno', axis=1, inplace=True)

# %%
df2
# Out:
#                        Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 0             V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 1           RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 2             MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 3      Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# 4            BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66
# ...                       ...        ...  ...   ...  ..   ...  ...    ...
# 1849        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*      -
# 1850     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*      -
# 1851       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0      0
# 1852           M Zondeki (SA)  2006-2006    1     1   0     0    0      0
# 1853  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0      0
#
#         BF      SR  100  50  0   4s   6s
# ...

# %% [markdown]
# ## 5- Select all players who have more then 3 hundreds

# %%
df2[df2['100'] > 3]
# Out:
#               Player       Span  Mat  Inns  NO  Runs   HS   Ave    BF      SR  \
# 1  RG Sharma (INDIA)  2007-2019  104    96  14  2633  118  32.1  1905  138.21
#
#    100  50  0   4s   6s
# 1    4  19  6  234  120

# %% [markdown]
# ## 6- Select all players who have highest score more then 50

# %%
df2['HS'] = df2['HS'].str.replace('*', '').astype('int')

# %%
df2[df2['HS'] > 50]
# Out:
#                      Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0           V Kohli (INDIA)  2010-2019   75    70  20  2633   94  52.66  1907
# 1         RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1  1905
# 2           MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36  1810
# 3    Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58  1824
# 4          BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66  1571
# ..                      ...        ...  ...   ...  ..   ...  ...    ...   ...
# 705     K Birkenstock (NAM)  2019-2019    4     2   0    64   59     32    33
# 706          S Dube (INDIA)  2019-2019    6     4   2    64   54     32    42
# 741      Muhammad Saleem ()  2019-2019    4     4   0    59   52  14.75    54
# 756          A Makesh (KUW)  2019-2019    4     2   1    57   57     57    41
# 776       Mirza Ahsan (Aut)  2019-2019    5     3   2    55   51     55    18
#
# ...

# %% [markdown]
# ## 7- How many players who have avg above 35?

# %%
avg_fd = df2[pd.to_numeric(df2['Ave'], errors='coerce').notna()]

# %%
avg_fd.loc[:,'Ave'] = avg_fd['Ave'].astype(float)

# %%
avg_fd[avg_fd.Ave > 35].sort_values(['Ave'], ascending=False)
# Out:
#                     Player       Span  Mat  Inns  NO  Runs   HS     Ave   BF  \
# 454  Najjam Shahzad (PORT)  2019-2019    4     3   2   126   53  126.00   97
# 487      Sami Sohail (MWI)  2019-2019    7     5   4   115   33  115.00   97
# 523       LA Dunbar (Serb)  2019-2019    2     2   1   104  104  104.00   62
# 347       S Davizi (CZK-R)  2019-2019    2     2   0   192  101   96.00  133
# 619      Muhammad Awais ()  2019-2019    3     3   2    82   42   82.00   59
# ..                     ...        ...  ...   ...  ..   ...  ...     ...  ...
# 414       Ehsan Khan (HKG)  2016-2019   15    10   6   142   42   35.50  128
# 418     Sarfaraz Ali (BAH)  2019-2019    4     4   0   141   59   35.25   87
# 178         SJ Baard (NAM)  2019-2019   13    13   2   387   92   35.18  305
# 95          JH Kallis (SA)  2005-2012   25    23   4   666   73   35.05  558
# 23        GJ Maxwell (AUS)  2012-2019   61    54   9  1576  145   35.02  985
#
#          SR  100  50  0   4s  6s
# ...
